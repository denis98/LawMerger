# %% [markdown]
# # Law Update

# %% [markdown]
# ## ToDos:
# 1. Bundesgesetzblattabschnitt in Anweisungen übersetzen
# 2. Anweisungen nacheinander Abarbeiten

# %%
from dotenv import dotenv_values
import getpass
import os

config = dotenv_values(".env")
os.environ["DEEPINFRA_API_TOKEN"] = config["DEEPINFRA_API_TOKEN"]

# %%
from typing import TypedDict, Annotated, List, Union, Literal
from pydantic import BaseModel, Field
from langchain.output_parsers import OutputFixingParser, PydanticOutputParser


# (Gesetz, Paragraph, Selector, Operation, newvalue, oldvalue) 
# Operation: Wähle zwischen "change", "drop", "insert"
class Instruction(BaseModel):
    law: str = Field("Name des betroffenen Gesetzes")
    paragraph: str = Field("Paragraph, in dem die Änderung vorgenommen werden soll. Beispiel: '§ 1'")
    selector: str = Field("Betroffener Abschnitt, z.B. 'Satz 1'")
    operation: Literal["change", "drop", "insert"]
    newvalue: str
    oldvalue: str

class Instructions(BaseModel):
    instructions: list[Instruction]


class LawSection(BaseModel):
    law: str = Field("Ausgeschriebener offizieller Name des Gesetzes")
    identifier: str = Field("Paragraph des Abschnittes. Das Feld muss eindeutig sein. Verwende nur den Paragraphen, erstelle nicht für jeden Absatz einen neuen Eintrag. Beispiele '§ 1', '§ 8'")
    title: str = Field("Titel des Paragraphen (falls vorhanden)")
    content: str = Field("Inhalt des Abschnittes. Auf keinen Fall verändern oder kürzen.")

class LawText(BaseModel):
    sections: list[LawSection]

# %%
from langchain_community.chat_models.deepinfra import ChatDeepInfra

llm = ChatDeepInfra(model_name="meta-llama/Llama-4-Scout-17B-16E-Instruct", max_tokens=100000)
print(llm.model_name)
parser_llm = ChatDeepInfra(model_name="google/gemma-3-27b-it", max_tokens=10000, temperature=0)

from langchain_core.messages import AIMessage, BaseMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.prompts import PromptTemplate


extract_template = """
Gehe folgende Anweisungen Schrtt für Schritt durch und erstelle jeweils folgende Datenstruktur:
(Operation, Gesetz, 'Paragraph', 'Selector', 'newvalue', 'oldvalue') 

Gesetz ist das Nachweisgesetz.
Paragraph entnimmst du den Änderungsanweisungen (z.B. "§ 1")
Selector steht auch in den Änderungsanweisungen (z.B. "Satz 1" oder "Absatz 1")
Operation: Wähle zwischen "change", "drop", "insert"

newvalue ist außer für drop immer notwendig.
oldvalue ist nur bei replace und change zu befüllen, sonst sollst du es weglassen. 
Es ist wichtig, dass du alle Änderungen aufschreibst.
Zwischen den Ausgaben sollen keine Aufzählungen oder sonstigen Kommentare sein.
Schneide keine Werte für 'newvalue' oder 'oldvalue' ab, vertausche diese Werte nicht!

{input}
"""

parser_prompt = PromptTemplate(
    input_variables=["instructions", "completion"],
    template="""
Your task is to fix the output of an LLM so that it matches the expected format.
Do NOT omit any content. Even when the passages are long.
{instructions}
Do only provide the valid JSON, no additional comments before or after it.
Do not fill values with ungiven placeholders.
Do not mix up the given values. You have to be very precise!
Old the order for the values.

Original output:
{completion}

Reformatted output:
""".strip()
)


pyparser = PydanticOutputParser(pydantic_object=Instructions)
parser = OutputFixingParser.from_llm(
    parser=pyparser,
    llm=parser_llm,
    max_retries=3,
    prompt=parser_prompt
)

print(pyparser.get_format_instructions())

extract_prompt = ChatPromptTemplate.from_template(extract_template)
extract_chain = extract_prompt | llm | parser
# Out:
# meta-llama/Llama-4-Scout-17B-16E-Instruct
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Instruction": {"properties": {"law": {"default": "Name des betroffenen Gesetzes", "title": "Law", "type": "string"}, "paragraph": {"default": "Paragraph, in dem die Änderung vorgenommen werden soll. Beispiel: '§ 1'", "title": "Paragraph", "type": "string"}, "selector": {"default": "Betroffener Abschnitt, z.B. 'Satz 1'", "title": "Selector", "type": "string"}, "operation": {"enum": ["change", "drop", "insert"], "title": "Operation", "type": "string"}, "newvalue": {"title": "Newvalue", "type": "string"}, "oldvalue": {"title": "Oldvalue", "type": "string"}}, "required": ["operation", "newvalue", "oldvalue"], "title": "Instruction", "type": "object"}}, "properties": {"instructions": {"items": {"$ref": "#/$defs/Instruction"}, "title": "Instructions", "type": "array"}}, "required": ["instructions"]}
# ```

# %%
parser_prompt = PromptTemplate(
    input_variables=["instructions", "completion"],
    template="""
Your task is to fix the output of an LLM so that it matches the expected format.
Do NOT omit any content. Even when the passages are long.
{instructions}
Do only provide the valid JSON, no additional comments before or after it.
Do not fill values with ungiven placeholders.

Original output:
{completion}

Reformatted output:
""".strip()
)

lawparser = OutputFixingParser.from_llm(
    parser=PydanticOutputParser(pydantic_object=LawText),
    llm=llm,
    max_retries=3,
    prompt=parser_prompt
)

lawchunker = ChatPromptTemplate.from_messages([
    ("system", "Du bist ein Experte im Auftrennen von Gesetzestexten nach Paragraphen. Ändere auf keinen Fall den Inhalt. Kürze nie etwas ab. Schreibe den Inhalt der Abschnitte vollständig ab.."),
    ("user", "{law}"),
])

law_parser_chain = lawchunker | llm | lawparser

# %%
update_base_template = """
Du bist ein Jura-Experte und aktualisiert Gesetzestexte genau nach der Vorgabe. Du kürzt keine Inhalte.
Füge keine Kommentare vor oder nach dem Inhalt hinzu. Kommentiere deine Arbeit nicht.

Alte Version:
{original}

Anweisung:
"""

change_template = update_base_template + """
Ersetze in {selector} '{oldvalue}' with '{newvalue}'.
Beachte, dass es mehrere passende vorkommen innerhalb des Selektors geben kann.
"""

drop_template = update_base_template + """
Entferne {selector} aus dem ursprünglichen Text.
Denke daran ggf. die Nummerierungen anzupassen.
"""

insert_template = update_base_template + """
Füge nach {selector} folgenden Text ein: {newvalue}
"""

change_chain = ChatPromptTemplate.from_template(change_template) | llm
drop_chain = ChatPromptTemplate.from_template(drop_template) | llm
insert_chain = ChatPromptTemplate.from_template(insert_template) | llm

# %%
from langgraph.graph import END
from langgraph.graph import StateGraph, START


class AmendmentParserState(TypedDict):
    text: str
    original: str
    amendments: str
    instructions: list[Instruction]
    sections: list[LawSection]



async def load_amendments(state: AmendmentParserState) -> AmendmentParserState:
    response = await extract_chain.ainvoke({"input": state.get("amendments")})
    
    return {"instructions": response.instructions}

async def parse_original_law(state: AmendmentParserState) -> AmendmentParserState:
    msg = HumanMessage(state.get("original", ""))
    msg.pretty_print()
    res = await law_parser_chain.ainvoke(input={msg.content})
    print(res)
    fin = await lawparser.ainvoke(res)
    return {
        "sections": fin.sections
    }

def get_instruction_and_section(state: AmendmentParserState):
    inst = state.get("instruction")[0]
    section = [section for section in fin.sections if section.identifier == inst.paragraph][0]
    return inst, section

async def change_passage(state: AmendmentParserState) -> AmendmentParserState:
    inst, section = get_instruction_and_section()
    
    res = await change_chain.ainvoke({
        "original": section.content,
        "selector": inst.selector,
        "oldvalue": inst.oldvalue,
        "newvalue": inst.newvalue
    })

    section.content = res.content
    sections = state.get("sections")
    sections = [section if s.identifier == section.identifier else s for s in sections]

    return {
        "sections": sections,
        "instructions": state.get("instructions")[1:]
    }

async def drop_passage(state: AmendmentParserState) -> AmendmentParserState:
    inst, section = get_instruction_and_section()

    res = await drop_chain.ainvoke({
        "original": section.content,
        "selector": inst.selector,
    })

    section.content = res.content
    sections = state.get("sections")
    sections = [section if s.identifier == section.identifier else s for s in sections]

    return {
        "sections": sections,
        "instructions": state.get("instructions")[1:]
    }

async def insert_passage(state: AmendmentParserState) -> AmendmentParserState:
    inst, section = get_instruction_and_section()

    res = await insert_chain.ainvoke({
        "original": section.content,
        "selector": inst.selector,
    })

    section.content = res.content
    sections = state.get("sections")
    sections = [section if s.identifier == section.identifier else s for s in sections]
    
    return {
        "sections": sections,
        "instructions": state.get("instructions")[1:]
    }

def router(state: AmendmentParserState) -> AmendmentParserState:
    print("Instruction")
    return {**state}

def route(state: AmendmentParserState) -> Literal["change", "drop", "insert", END]:
    return state.get("instructions")[0].operation

def empty(state: AmendmentParserState) -> Literal["Empty", "Not Empty"]:
    if len(state.get("instruction", [])) == 0:
        return "Empty"
    return "Not Empty"

def instruction_end(state: AmendmentParserState) -> AmendmentParserState:
    return {**state}



workflow = StateGraph(AmendmentParserState)
workflow.add_node("load_instruction", load_amendments)
workflow.add_node("load_original", parse_original_law)
workflow.add_node("router", router)
workflow.add_node("change", change_passage)
workflow.add_node("drop", drop_passage)
workflow.add_node("insert", insert_passage)
workflow.add_node("instruction_end", instruction_end)

workflow.add_edge(START, "load_instruction")
workflow.add_edge("load_original", "router")

workflow.add_conditional_edges("load_instruction", empty, {
    "Empty": END,
    "Not Empty": 'load_original'
})

workflow.add_conditional_edges("router", route, {
    "change": "change",
    "drop": "drop",
    "insert": "insert",
})

workflow.add_edge("change", "instruction_end")
workflow.add_edge("drop", "instruction_end")
workflow.add_edge("insert", "instruction_end")

workflow.add_conditional_edges("instruction_end", empty, {
    "Empty": END,
    "Not Empty": "router"
})


app = workflow.compile()

# %%
try:
    # Laden der Änderungen aus dem Bundesgesetzblatt
    with open("short_changes.txt") as file:
        amendments = file.read()

    # Laden der alten Version des Gesetzes
    with open("short_law.txt") as file:
        nachweisg = file.read()
except Exception as e:
    print("couldnt read file")


law = await app.ainvoke({
    "text": nachweisg,
    "amendments": amendments,
    "original": nachweisg,
    "instructions": [],
    "sections": []
})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/output_parsers/pydantic.py:30, in PydanticOutputParser._parse_obj(self, obj)
#      29 if issubclass(self.pydantic_object, pydantic.BaseModel):
# ---> 30     return self.pydantic_object.model_validate(obj)
#      31 if issubclass(self.pydantic_object, pydantic.v1.BaseModel):
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/pydantic/main.py:627, in BaseModel.model_validate(cls, obj, strict, from_attributes, context)
#     626 __tracebackhide__ = True
# --> 627 return cls.__pydantic_validator__.validate_python(
#     628     obj, strict=strict, from_attributes=from_attributes, context=context
#     629 )
#
# ValidationError: 2 validation errors for Instructions
# instructions.3.operation
#   Input should be 'change', 'drop' or 'insert' [type=literal_error, input_value='replace', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/literal_error
# instructions.7.operation
#   Input should be 'change', 'drop' or 'insert' [type=literal_error, input_value='replace', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/literal_error
#
# The above exception was the direct cause of the following exception:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[23], line 13
#       9 except Exception as e:
#      10     print("couldnt read file")
# ---> 13 law = await app.ainvoke({
#      14     "text": nachweisg,
#      15     "amendments": amendments,
#      16     "original": nachweisg,
#      17     "instructions": [],
#      18     "sections": []
#      19 })
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2428, in Pregel.ainvoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2426 else:
#    2427     chunks = []
# -> 2428 async for chunk in self.astream(
#    2429     input,
#    2430     config,
#    2431     stream_mode=stream_mode,
#    2432     output_keys=output_keys,
#    2433     interrupt_before=interrupt_before,
#    2434     interrupt_after=interrupt_after,
#    2435     debug=debug,
#    2436     **kwargs,
#    2437 ):
#    2438     if stream_mode == "values":
#    2439         latest = chunk
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2313, in Pregel.astream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2307 # Similarly to Bulk Synchronous Parallel / Pregel model
#    2308 # computation proceeds in steps, while there are channel updates
#    2309 # channel updates from step N are only visible in step N+1
#    2310 # channels are guaranteed to be immutable for the duration of the step,
#    2311 # with channel updates applied only at the transition between steps
#    2312 while loop.tick(input_keys=self.input_channels):
# -> 2313     async for _ in runner.atick(
#    2314         loop.tasks.values(),
#    2315         timeout=self.step_timeout,
#    2316         retry_policy=self.retry_policy,
#    2317         get_waiter=get_waiter,
#    2318     ):
#    2319         # emit output
#    2320         for o in output():
#    2321             yield o
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langgraph/pregel/runner.py:444, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     442 t = tasks[0]
#     443 try:
# --> 444     await arun_with_retry(
#     445         t,
#     446         retry_policy,
#     447         stream=self.use_astream,
#     448         configurable={
#     449             CONFIG_KEY_SEND: partial(writer, t),
#     450             CONFIG_KEY_CALL: partial(call, t),
#     451         },
#     452     )
#     453     self.commit(t, None)
#     454 except Exception as exc:
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langgraph/pregel/retry.py:128, in arun_with_retry(task, retry_policy, stream, configurable)
#     126         break
#     127     else:
# --> 128         return await task.proc.ainvoke(task.input, config)
#     129 except ParentCommand as exc:
#     130     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langgraph/utils/runnable.py:583, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     579 config = patch_config(
#     580     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     581 )
#     582 if i == 0:
# --> 583     input = await step.ainvoke(input, config, **kwargs)
#     584 else:
#     585     input = await step.ainvoke(input, config)
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langgraph/utils/runnable.py:371, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     369 if ASYNCIO_ACCEPTS_CONTEXT:
#     370     coro = cast(Coroutine[None, None, Any], self.afunc(*args, **kwargs))
# --> 371     ret = await asyncio.create_task(coro, context=context)
#     372 else:
#     373     ret = await self.afunc(*args, **kwargs)
#
# Cell In[22], line 15, in load_amendments(state)
#      14 async def load_amendments(state: AmendmentParserState) -> AmendmentParserState:
# ---> 15     response = await extract_chain.ainvoke({"input": state.get("amendments")})
#      17     return {"instructions": response.instructions}
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/runnables/base.py:3075, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    3073             else:
#    3074                 part = functools.partial(step.ainvoke, input, config)
# -> 3075             input = await coro_with_context(part(), context, create_task=True)
#    3076     # finish the root run
#    3077 except BaseException as e:
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:219, in BaseOutputParser.ainvoke(self, input, config, **kwargs)
#     211 @override
#     212 async def ainvoke(
#     213     self,
#    (...)
#     216     **kwargs: Optional[Any],
#     217 ) -> T:
#     218     if isinstance(input, BaseMessage):
# --> 219         return await self._acall_with_config(
#     220             lambda inner_input: self.aparse_result(
#     221                 [ChatGeneration(message=inner_input)]
#     222             ),
#     223             input,
#     224             config,
#     225             run_type="parser",
#     226         )
#     227     return await self._acall_with_config(
#     228         lambda inner_input: self.aparse_result([Generation(text=inner_input)]),
#     229         input,
#     230         config,
#     231         run_type="parser",
#     232     )
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/runnables/base.py:1981, in Runnable._acall_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1977     with set_config_context(child_config) as context:
#    1978         coro = acall_func_with_variable_args(
#    1979             func, input, config, run_manager, **kwargs
#    1980         )
# -> 1981         output: Output = await coro_with_context(coro, context)
#    1982 except BaseException as e:
#    1983     await run_manager.on_chain_error(e)
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:280, in BaseOutputParser.aparse_result(self, result, partial)
#     263 async def aparse_result(
#     264     self, result: list[Generation], *, partial: bool = False
#     265 ) -> T:
#     266     """Async parse a list of candidate model Generations into a specific format.
#     267
#     268     The return value is parsed from only the first Generation in the result, which
#    (...)
#     278         Structured output.
#     279     """
# --> 280     return await run_in_executor(None, self.parse_result, result, partial=partial)
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/runnables/config.py:616, in run_in_executor(executor_or_config, func, *args, **kwargs)
#     612         raise RuntimeError from exc
#     614 if executor_or_config is None or isinstance(executor_or_config, dict):
#     615     # Use default executor with context copied from current context
# --> 616     return await asyncio.get_running_loop().run_in_executor(
#     617         None,
#     618         cast("Callable[..., T]", partial(copy_context().run, wrapper)),
#     619     )
#     621 return await asyncio.get_running_loop().run_in_executor(executor_or_config, wrapper)
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/runnables/config.py:607, in run_in_executor.<locals>.wrapper()
#     605 def wrapper() -> T:
#     606     try:
# --> 607         return func(*args, **kwargs)
#     608     except StopIteration as exc:
#     609         # StopIteration can't be set on an asyncio.Future
#     610         # it raises a TypeError and leaves the Future pending forever
#     611         # so we need to convert it to a RuntimeError
#     612         raise RuntimeError from exc
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:250, in BaseOutputParser.parse_result(self, result, partial)
#     234 @override
#     235 def parse_result(self, result: list[Generation], *, partial: bool = False) -> T:
#     236     """Parse a list of candidate model Generations into a specific format.
#     237
#     238     The return value is parsed from only the first Generation in the result, which
#    (...)
#     248         Structured output.
#     249     """
# --> 250     return self.parse(result[0].text)
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain/output_parsers/fix.py:73, in OutputFixingParser.parse(self, completion)
#      71 except OutputParserException as e:
#      72     if retries == self.max_retries:
# ---> 73         raise e
#      74     else:
#      75         retries += 1
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain/output_parsers/fix.py:70, in OutputFixingParser.parse(self, completion)
#      68 while retries <= self.max_retries:
#      69     try:
# ---> 70         return self.parser.parse(completion)
#      71     except OutputParserException as e:
#      72         if retries == self.max_retries:
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/output_parsers/pydantic.py:84, in PydanticOutputParser.parse(self, text)
#      75 def parse(self, text: str) -> TBaseModel:
#      76     """Parse the output of an LLM call to a pydantic object.
#      77
#      78     Args:
#    (...)
#      82         The parsed pydantic object.
#      83     """
# ---> 84     return super().parse(text)
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/output_parsers/json.py:100, in JsonOutputParser.parse(self, text)
#      91 def parse(self, text: str) -> Any:
#      92     """Parse the output of an LLM call to a JSON object.
#      93
#      94     Args:
#    (...)
#      98         The parsed JSON object.
#      99     """
# --> 100     return self.parse_result([Generation(text=text)])
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/output_parsers/pydantic.py:69, in PydanticOutputParser.parse_result(self, result, partial)
#      67 try:
#      68     json_object = super().parse_result(result)
# ---> 69     return self._parse_obj(json_object)
#      70 except OutputParserException:
#      71     if partial:
#
# File /opt/anaconda3/envs/masterarbeit/lib/python3.12/site-packages/langchain_core/output_parsers/pydantic.py:37, in PydanticOutputParser._parse_obj(self, obj)
#      35         raise OutputParserException(msg)
#      36     except (pydantic.ValidationError, pydantic.v1.ValidationError) as e:
# ---> 37         raise self._parser_exception(e, obj) from e
#      38 else:  # pydantic v1
#      39     try:
#
# OutputParserException: Failed to parse Instructions from completion {"instructions": [{"operation": "change", "law": "Nachweisgesetz", "paragraph": "\u00a7 2", "selector": "Satz 1", "newvalue": "Satzes 9", "oldvalue": "Satzes 4"}, {"operation": "insert", "law": "Nachweisgesetz", "paragraph": "\u00a7 2", "selector": "Absatz 2 Satz 1", "newvalue": "Die Arbeitgeberin oder der Arbeitgeber hat der Arbeitnehmerin oder dem Arbeitnehmer mit der ersten schriftlichen oder elektronischen Mitteilung \u00fcber die Bedingungen der  Begr\u00fcndung eines Arbeitsverh\u00e4ltnisses insbesondere die  in \u00a7 3 Absatz 1 genannten Angaben  schriftlich oder elektronisch  zu  \u00fcbermitteln.", "oldvalue": ""}, {"operation": "change", "law": "Nachweisgesetz", "paragraph": "\u00a7 2", "selector": "Satz 1", "newvalue": "der Arbeitnehmerin oder des Arbeitnehmers", "oldvalue": "des Arbeitnehmers oder der Arbeitnehmerin"}, {"operation": "replace", "law": "Nachweisgesetz", "paragraph": "\u00a7 3", "selector": "Absatz 1 Nummer 1", "newvalue": "1.  die  Identit\u00e4t  der  Arbeitgeberin  oder  des  Arbeitgebers  und  die  eigene  Identit\u00e4t  der  Arbeitnehmerin oder des Arbeitnehmers;", "oldvalue": ""}, {"operation": "change", "law": "Nachweisgesetz", "paragraph": "\u00a7 3", "selector": "Satz 2", "newvalue": "vor  der  Begr\u00fcndung", "oldvalue": "vor der Begr\u00fcndung"}, {"operation": "change", "law": "Nachweisgesetz", "paragraph": "\u00a7 3", "selector": "Satz 1", "newvalue": "\u00a7 2 Absatz 1", "oldvalue": "\u00a7 2 Absatz 1 Satz 1"}, {"operation": "change", "law": "Nachweisgesetz", "paragraph": "\u00a7 3", "selector": "Satz 1", "newvalue": "\u00a7 2 Absatz 3", "oldvalue": "\u00a7 2 Absatz 2"}, {"operation": "replace", "law": "Nachweisgesetz", "paragraph": "\u00a7 4", "selector": "Absatz 1 Satz 1", "newvalue": "Die  Arbeitnehmerin  oder  der  Arbeitnehmer  kann  von  der  Arbeitgeberin  oder  dem  Arbeitgeber  insoweit  die  Erteilung  der  Angaben  nach  \u00a7 3  Absatz  1  Nummer  1  bis  7 ,  9  und  10 , nach \u00a7 4 Absatz 1 Satz 1 Nummer 1 bis 3 und nach \u00a7 11 Absatz 1 Satz 1 verlangen.", "oldvalue": ""}, {"operation": "change", "law": "Nachweisgesetz", "paragraph": "\u00a7 5", "selector": "Satz 1", "newvalue": "bis zum 31. Dezember 2024", "oldvalue": "bis zum 31. Dezember 2023"}, {"operation": "change", "law": "Nachweisgesetz", "paragraph": "\u00a7 5", "selector": "Satz 2", "newvalue": "bis zum 31. Dezember 2024", "oldvalue": "bis zum 31. Dezember 2023"}, {"operation": "change", "law": "Nachweisgesetz", "paragraph": "\u00a7 12", "selector": "Satz 1", "newvalue": "am 1. August 2024", "oldvalue": "am 1. August 2023"}, {"operation": "change", "law": "Nachweisgesetz", "paragraph": "\u00a7 12", "selector": "Satz 2", "newvalue": "am 1. August 2024", "oldvalue": "am 1. August 2023"}, {"operation": "insert", "law": "Nachweisgesetz", "paragraph": "\u00a7 12", "selector": "Absatz 2 Satz 1", "newvalue": "F\u00fcr die erstmalige Anwendung des \u00a7 2 Absatz 2 Satz 1 und des \u00a7 3 Absatz 1 Nummer 1 bis 7, 9 und 10 am 1. August 2024  gilt  \u00a7  2  Absatz  4  und  \u00a7  4  Absatz  2  entsprechend  mit  der  Ma\u00dfgabe , dass anstelle  des  dort  genannten  Zeitpunkts  der 1. August 2024  ma\u00dfgeblich  ist .", "oldvalue": ""}, {"operation": "insert", "law": "Nachweisgesetz", "paragraph": "\u00a7 12", "selector": "Absatz 3 Satz 1", "newvalue": "Abweichend  von  Satz  1  und  2  k\u00f6nnen  Arbeitgeber  und  Arbeitnehmer  bis  zum  31 .  Dezember 2024  eine  Vereinbarung  \u00fcber  die  elektronische  \u00dcbermittlung  von  Angaben  nach  diesem  Gesetz schlie\u00dfen .", "oldvalue": ""}]}. Got: 2 validation errors for Instructions
# instructions.3.operation
#   Input should be 'change', 'drop' or 'insert' [type=literal_error, input_value='replace', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/literal_error
# instructions.7.operation
#   Input should be 'change', 'drop' or 'insert' [type=literal_error, input_value='replace', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/literal_error
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE

# %%
    
try:
    # Laden der Änderungen aus dem Bundesgesetzblatt
    with open("changes.txt") as file:
        amendments = file.read()

    # Laden der alten Version des Gesetzes
    with open("nachweisg.txt") as file:
        nachweisg = file.read()
except e:
    print("couldnt read file")


a = await load_amendments({
    "text": nachweisg,
    "amendments": amendments,
    "original": nachweisg,
    "instructions": [],
    "sections": []
})

print(a)

# %%
a.get("instructions")[0]

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles
img = app.get_graph().draw_mermaid_png(
    draw_method=MermaidDrawMethod.API,
)
display(
    Image(
        img
    )
)

with open("graph.png", "wb") as file:
    file.write(img)
